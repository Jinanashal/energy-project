# %%
# impoerting library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading csv file
data=pd.read_csv('energydata.csv')

# %%
data
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 0      11-01-2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      11-01-2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      11-01-2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      11-01-2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      11-01-2016 17:40          60      40  19.890000  46.333333  19.200000
# ...                 ...         ...     ...        ...        ...        ...
# 19730  27-05-2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00         430      10  25.500000  46.600000  25.264286
#
# ...

# %%
# convert to dataframe 
df=pd.DataFrame(data)

# %%
df
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 0      11-01-2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      11-01-2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      11-01-2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      11-01-2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      11-01-2016 17:40          60      40  19.890000  46.333333  19.200000
# ...                 ...         ...     ...        ...        ...        ...
# 19730  27-05-2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00         430      10  25.500000  46.600000  25.264286
#
# ...

# %%
#top 10 rows
df.head(10)
# Out:
#                date  Appliances  lights         T1       RH_1     T2  \
# 0  11-01-2016 17:00          60      30  19.890000  47.596667  19.20
# 1  11-01-2016 17:10          60      30  19.890000  46.693333  19.20
# 2  11-01-2016 17:20          50      30  19.890000  46.300000  19.20
# 3  11-01-2016 17:30          50      40  19.890000  46.066667  19.20
# 4  11-01-2016 17:40          60      40  19.890000  46.333333  19.20
# 5  11-01-2016 17:50          50      40  19.890000  46.026667  19.20
# 6  11-01-2016 18:00          60      50  19.890000  45.766667  19.20
# 7  11-01-2016 18:10          60      50  19.856667  45.560000  19.20
# 8  11-01-2016 18:20          60      40  19.790000  45.597500  19.20
# 9  11-01-2016 18:30          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9  T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60
# ...

# %%
#last 5 rows
df.tail(5)
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 19730  27-05-2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00         430      10  25.500000  46.600000  25.264286
#
#             RH_2         T3       RH_3    T4  ...    T9     RH_9  T_out  \
# 19730  42.025714  27.200000  41.163333  24.7  ...  23.2  46.7900   22.7
# 19731  42.080000  27.133333  41.223333  24.7  ...  23.2  46.7900   22.6
# 19732  42.768571  27.050000  41.690000  24.7  ...  23.2  46.7900   22.5
# 19733  43.036000  26.890000  41.290000  24.7  ...  23.2  46.8175   22.3
# 19734  42.971429  26.823333  41.156667  24.7  ...  23.2  46.8450   22.2
#
# ...

# %%
# checking information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
# numerical data describtion 
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
# checking shape
df.shape
# Out:
# (19735, 29)

# %%
# checking names of column 
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
# checking data tyoes
df.dtypes
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %% [markdown]
# *handling missing value*
# -------------------------

# %%
# checking null values
df.isnull()
# Out:
#         date  Appliances  lights     T1   RH_1     T2   RH_2     T3   RH_3  \
# 0      False       False   False  False  False  False  False  False  False
# 1      False       False   False  False  False  False  False  False  False
# 2      False       False   False  False  False  False  False  False  False
# 3      False       False   False  False  False  False  False  False  False
# 4      False       False   False  False  False  False  False  False  False
# ...      ...         ...     ...    ...    ...    ...    ...    ...    ...
# 19730  False       False   False  False  False  False  False  False  False
# 19731  False       False   False  False  False  False  False  False  False
# 19732  False       False   False  False  False  False  False  False  False
# 19733  False       False   False  False  False  False  False  False  False
# 19734  False       False   False  False  False  False  False  False  False
#
# ...

# %%
# checking null value
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %% [markdown]
# *handling duplicates*
# -----------------------

# %%
# checking duplicates
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19730    False
# 19731    False
# 19732    False
# 19733    False
# 19734    False
# Length: 19735, dtype: bool

# %%
#checking duplucates with sum 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(5)
# Out:
#                date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  11-01-2016 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  11-01-2016 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  11-01-2016 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  11-01-2016 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  11-01-2016 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9  T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56   6.48        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50   6.37        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40   6.25        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40   6.13        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
# renaming a column
df=df.rename(columns={'Appliances':'ENERGY'})

# %%
df
# Out:
#                    date  ENERGY  lights         T1       RH_1         T2  \
# 0      11-01-2016 17:00      60      30  19.890000  47.596667  19.200000
# 1      11-01-2016 17:10      60      30  19.890000  46.693333  19.200000
# 2      11-01-2016 17:20      50      30  19.890000  46.300000  19.200000
# 3      11-01-2016 17:30      50      40  19.890000  46.066667  19.200000
# 4      11-01-2016 17:40      60      40  19.890000  46.333333  19.200000
# ...                 ...     ...     ...        ...        ...        ...
# 19730  27-05-2016 17:20     100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30      90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40     270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50     420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00     430      10  25.500000  46.600000  25.264286
#
#             RH_2         T3       RH_3         T4  ...         T9     RH_9  \
# ...

# %%
# renaming the column 
df=df.rename(columns={'T1':'TEMP1',
                      'RH_1':'HUM1',
                      'T2':'TEMP2',
                      'RH_2':'HUM2',
                      'T3':'TEMP3',
                      'RH_3':'HUM3',
                      'T4':'TEMP4',
                      'RH_4':'HUM4',
                      'T5':'TEMP5',
                      'RH_5':'HUM5',
                      'T6':'TEMP6',
                      'RH_6':'HUM6',
                      'T7':'TEMP7',
                      'RH_7':'HUM7',
                      'T8':'TEMP8',
                      'RH_8':'HUM8',
                      'T9':'TEMP9',
                      'RH_9':'HUM9',
                      'RH_out':'HUM_OUT',
                      'Press_mm_hg':'PRESSURE'})

# %%
df
# Out:
#                    date  ENERGY  lights      TEMP1       HUM1      TEMP2  \
# 0      11-01-2016 17:00      60      30  19.890000  47.596667  19.200000
# 1      11-01-2016 17:10      60      30  19.890000  46.693333  19.200000
# 2      11-01-2016 17:20      50      30  19.890000  46.300000  19.200000
# 3      11-01-2016 17:30      50      40  19.890000  46.066667  19.200000
# 4      11-01-2016 17:40      60      40  19.890000  46.333333  19.200000
# ...                 ...     ...     ...        ...        ...        ...
# 19730  27-05-2016 17:20     100       0  25.566667  46.560000  25.890000
# 19731  27-05-2016 17:30      90       0  25.500000  46.500000  25.754000
# 19732  27-05-2016 17:40     270      10  25.500000  46.596667  25.628571
# 19733  27-05-2016 17:50     420      10  25.500000  46.990000  25.414000
# 19734  27-05-2016 18:00     430      10  25.500000  46.600000  25.264286
#
#             HUM2      TEMP3       HUM3      TEMP4  ...      TEMP9     HUM9  \
# ...

# %%
# checking information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        19735 non-null  object
#  1   ENERGY      19735 non-null  int64
#  2   lights      19735 non-null  int64
#  3   TEMP1       19735 non-null  float64
#  4   HUM1        19735 non-null  float64
#  5   TEMP2       19735 non-null  float64
#  6   HUM2        19735 non-null  float64
#  7   TEMP3       19735 non-null  float64
#  8   HUM3        19735 non-null  float64
#  9   TEMP4       19735 non-null  float64
#  10  HUM4        19735 non-null  float64
#  11  TEMP5       19735 non-null  float64
#  12  HUM5        19735 non-null  float64
#  13  TEMP6       19735 non-null  float64
#  14  HUM6        19735 non-null  float64
#  15  TEMP7       19735 non-null  float64
#  16  HUM7        19735 non-null  float64
#  17  TEMP8       19735 non-null  float64
# ...

# %%
c=df.corr(numeric_only=True)

# %%
c
# Out:
#               ENERGY    lights     TEMP1      HUM1     TEMP2      HUM2  \
# ENERGY      1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights      0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# TEMP1       0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# HUM1        0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# TEMP2       0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# HUM2       -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# TEMP3       0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# HUM3        0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# TEMP4       0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# HUM4        0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# TEMP5       0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# HUM5        0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
plt.figure(figsize=(18,10))
sns.heatmap(c,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
num_col=df.select_dtypes(include='number').columns
for col in num_col:
    sns.boxplot(data=df,y=col)
    plt.title(f'boxplot for {col}')
    plt.grid(True)
    plt.show()

# %%
def handling_outliers(df):            #handling outliers
    for col in df.select_dtypes(include='number').columns:
        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        IQR=Q3-Q1
        lower_bound=Q1-(1.5*IQR)
        upper_bound=Q3+(1.5*IQR)
        #Capping
        df[col]=df[col].apply(lambda x:lower_bound if x<lower_bound else upper_bound
                              if x>upper_bound else x)
    return df

# %%
df1=handling_outliers(df)

# %%
df1
# Out:
#                    date  ENERGY  lights  TEMP1       HUM1      TEMP2  \
# 0      11-01-2016 17:00    60.0     0.0  19.89  47.596667  19.200000
# 1      11-01-2016 17:10    60.0     0.0  19.89  46.693333  19.200000
# 2      11-01-2016 17:20    50.0     0.0  19.89  46.300000  19.200000
# 3      11-01-2016 17:30    50.0     0.0  19.89  46.066667  19.200000
# 4      11-01-2016 17:40    60.0     0.0  19.89  46.333333  19.200000
# ...                 ...     ...     ...    ...        ...        ...
# 19730  27-05-2016 17:20   100.0     0.0  25.36  46.560000  25.565000
# 19731  27-05-2016 17:30    90.0     0.0  25.36  46.500000  25.565000
# 19732  27-05-2016 17:40   175.0     0.0  25.36  46.596667  25.565000
# 19733  27-05-2016 17:50   175.0     0.0  25.36  46.990000  25.414000
# 19734  27-05-2016 18:00   175.0     0.0  25.36  46.600000  25.264286
#
#             HUM2      TEMP3       HUM3      TEMP4  ...      TEMP9     HUM9  \
# ...

# %%
sns.boxplot(data=df1)
# Out:
# <Axes: >

# %%
x=df1['TEMP2']
y=df1['HUM5']

# %%
plt.plot(x,y)

# %%
sns.histplot(df1['ENERGY'],kde=True)
# Out:
# <Axes: xlabel='ENERGY', ylabel='Count'>

# %%
sns.histplot(df1['TEMP1'],kde=True)
# Out:
# <Axes: xlabel='TEMP1', ylabel='Count'>

# %%
sns.histplot(df1['HUM1'],kde=True)
# Out:
# <Axes: xlabel='HUM1', ylabel='Count'>

# %%
df1.skew()
# Out:
# ENERGY        1.156157
# lights        0.000000
# TEMP1         0.166939
# HUM1          0.401822
# TEMP2         0.634604
# HUM2         -0.146187
# TEMP3         0.383435
# HUM3          0.466830
# TEMP4         0.192775
# HUM4          0.444614
# TEMP5         0.534076
# HUM5          0.734540
# TEMP6         0.456428
# HUM6         -0.241961
# TEMP7         0.254697
# HUM7          0.237275
# TEMP8        -0.246628
# HUM8          0.305941
# TEMP9         0.382711
# HUM9          0.370684
# T_out         0.396798
# PRESSURE     -0.338726
# HUM_OUT      -0.846254
# Windspeed     0.790130
# Visibility    0.157975
# Tdewpoint     0.239644
# rv1           0.004945
# rv2           0.004945
# dtype: float64

# %%
df1=df1.drop('date',axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ENERGY      19735 non-null  float64
#  1   lights      19735 non-null  float64
#  2   TEMP1       19735 non-null  float64
#  3   HUM1        19735 non-null  float64
#  4   TEMP2       19735 non-null  float64
#  5   HUM2        19735 non-null  float64
#  6   TEMP3       19735 non-null  float64
#  7   HUM3        19735 non-null  float64
#  8   TEMP4       19735 non-null  float64
#  9   HUM4        19735 non-null  float64
#  10  TEMP5       19735 non-null  float64
#  11  HUM5        19735 non-null  float64
#  12  TEMP6       19735 non-null  float64
#  13  HUM6        19735 non-null  float64
#  14  TEMP7       19735 non-null  float64
#  15  HUM7        19735 non-null  float64
#  16  TEMP8       19735 non-null  float64
#  17  HUM8        19735 non-null  float64
# ...

# %%
df1.head(5)
# Out:
#    ENERGY  lights  TEMP1       HUM1  TEMP2       HUM2  TEMP3       HUM3  \
# 0    60.0     0.0  19.89  47.596667   19.2  44.790000  19.79  44.730000
# 1    60.0     0.0  19.89  46.693333   19.2  44.722500  19.79  44.790000
# 2    50.0     0.0  19.89  46.300000   19.2  44.626667  19.79  44.933333
# 3    50.0     0.0  19.89  46.066667   19.2  44.590000  19.79  45.000000
# 4    60.0     0.0  19.89  46.333333   19.2  44.530000  19.79  45.000000
#
#        TEMP4       HUM4  ...      TEMP9   HUM9  T_out    PRESSURE  HUM_OUT  \
# 0  19.000000  45.566667  ...  17.033333  45.53   6.60  735.933333     92.0
# 1  19.000000  45.992500  ...  17.066667  45.56   6.48  735.933333     92.0
# 2  18.926667  45.890000  ...  17.000000  45.50   6.37  735.933333     92.0
# 3  18.890000  45.723333  ...  17.000000  45.40   6.25  735.933333     92.0
# 4  18.890000  45.530000  ...  17.000000  45.40   6.13  735.933333     92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
# CHECKING VALUE COUNT
df1['ENERGY'].value_counts()
# Out:
# ENERGY
# 50.0     4368
# 60.0     3282
# 175.0    2138
# 40.0     2019
# 70.0     1560
# 80.0     1205
# 90.0     1015
# 100.0     978
# 110.0     736
# 30.0      723
# 120.0     502
# 20.0      343
# 130.0     330
# 140.0     223
# 150.0     144
# 160.0      90
# 170.0      70
# 10.0        9
# Name: count, dtype: int64
